# %% [markdown]
# ## 1. Introduction
# <p><img src="https://assets.datacamp.com/production/project_1197/img/google_play_store.png" alt="Google Play logo"></p>
# <p>Mobile apps are everywhere. They are easy to create and can be very lucrative from the business standpoint. Specifically, Android is expanding as an operating system and has captured more than 74% of the total market<sup><a href="https://www.statista.com/statistics/272698/global-market-share-held-by-mobile-operating-systems-since-2009">[1]</a></sup>. </p>
# <p>The Google Play Store apps data has enormous potential to facilitate data-driven decisions and insights for businesses. In this notebook, we will analyze the Android app market by comparing ~10k apps in Google Play across different categories. We will also use the user reviews to draw a qualitative comparision between the apps.</p>
# <p>The dataset you will use here was scraped from Google Play Store in September 2018 and was published on <a href="https://www.kaggle.com/lava18/google-play-store-apps">Kaggle</a>. Here are the details: <br>
# <br></p>
# <div style="background-color: #efebe4; color: #05192d; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/apps.csv</b></div>
# This file contains all the details of the apps on Google Play. There are 9 features that describe a given app.
# <ul>
#     <li><b>App:</b> Name of the app</li>
#     <li><b>Category:</b> Category of the app. Some examples are: ART_AND_DESIGN, FINANCE, COMICS, BEAUTY etc.</li>
#     <li><b>Rating:</b> The current average rating (out of 5) of the app on Google Play</li>
#     <li><b>Reviews:</b> Number of user reviews given on the app</li>
#     <li><b>Size:</b> Size of the app in MB (megabytes)</li>
#     <li><b>Installs:</b> Number of times the app was downloaded from Google Play</li>
#     <li><b>Type:</b> Whether the app is paid or free</li>
#     <li><b>Price:</b> Price of the app in US$</li>
#     <li><b>Last Updated:</b> Date on which the app was last updated on Google Play </li>
#
# </ul>
# </div>
# <div style="background-color: #efebe4; color: #05192d; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/user_reviews.csv</b></div>
# This file contains a random sample of 100 <i>[most helpful first](https://www.androidpolice.com/2019/01/21/google-play-stores-redesigned-ratings-and-reviews-section-lets-you-easily-filter-by-star-rating/)</i> user reviews for each app. The text in each review has been pre-processed and passed through a sentiment analyzer.
# <ul>
#     <li><b>App:</b> Name of the app on which the user review was provided. Matches the `App` column of the `apps.csv` file</li>
#     <li><b>Review:</b> The pre-processed user review text</li>
#     <li><b>Sentiment Category:</b> Sentiment category of the user review - Positive, Negative or Neutral</li>
#     <li><b>Sentiment Score:</b> Sentiment score of the user review. It lies between [-1,1]. A higher score denotes a more positive sentiment.</li>
#
# </ul>
# </div>
# <p>From here on, it will be your task to explore and manipulate the data until you are able to answer the three questions described in the instructions panel.<br></p>

# %% [markdown]
# **CODE BEGINS HERE**

# %% [markdown]
# Import the relevant modules and load the two csv files as DataFrame.

# %%
import pandas as pd

# %%
apps = pd.read_csv('datasets/apps.csv')
reviews = pd.read_csv('datasets/user_reviews.csv')

# %% [markdown]
# Let's get a thorough insight on the dataset using the .info() and .head() methods on the two DataFrames.

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   App           9659 non-null   object
#  1   Category      9659 non-null   object
#  2   Rating        8196 non-null   float64
#  3   Reviews       9659 non-null   int64
#  4   Size          8432 non-null   float64
#  5   Installs      9659 non-null   object
#  6   Type          9659 non-null   object
#  7   Price         9659 non-null   float64
#  8   Last Updated  9659 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 679.3+ KB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 64295 non-null  object
#  1   Review              37427 non-null  object
#  2   Sentiment Category  37432 non-null  object
#  3   Sentiment Score     37432 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ MB

# %%
reviews.head()
# Out:
#                      App                                             Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment Category  Sentiment Score
# 0           Positive             1.00
# 1           Positive             0.25
# 2                NaN              NaN
# 3           Positive             0.40
# 4           Positive             1.00

# %% [markdown]
# The .sample() method is used to generate a random sample of data from the DataFrame. It is better than the .head() method as more diverse data can be examined.

# %%
apps.sample(10)
# Out:
#                                                     App         Category  \
# 3341                        My Android Device S/W & H/W           FAMILY
# 8719                         Flag Of European Union LWP  PERSONALIZATION
# 7525               Cursive Writing Wizard - Handwriting           FAMILY
# 6042                                      CA Mobile OTP            TOOLS
# 8170                                           EF Forms         BUSINESS
# 498   Chatting - Free chat, random chat, boyfriend, ...           DATING
# 7398                            Salah Widget (DK+Malmo)        LIFESTYLE
# 5023                                          Upohar BD         BUSINESS
# 7454                                         DM airdisk            TOOLS
# 2571                      Fraction Calculator Plus Free            TOOLS
#
#       Rating  Reviews  Size    Installs  Type  Price       Last Updated
# 3341     4.5      681   2.8     50,000+  Free    0.0  November 20, 2015
# 8719     4.3       88   4.2      1,000+  Free    0.0   January 24, 2018
# 7525     4.0     3745  31.0  1,000,000+  Free    0.0   December 3, 2017
# 6042     3.3      688   5.5    100,000+  Free    0.0  September 5, 2017
# 8170     5.0        2  23.0         50+  Free    0.0      July 24, 2018
# 498      4.2     2506   6.1    500,000+  Free    0.0      June 15, 2017
# 7398     4.5      532   6.4     10,000+  Free    0.0      June 28, 2015
# 5023     3.4        9   1.7      1,000+  Free    0.0    October 8, 2016
# 7454     2.8       11  11.0      1,000+  Free    0.0     August 5, 2016
# 2571     4.5   148506  11.0  5,000,000+  Free    0.0      July 15, 2018

# %% [markdown]
# The first task was to convert the values on 'Installs' column in the dataset to an integer value. Originally, the 'Installs' column contained String values.
#
#
# To convert the column to integer, we first need to remove special signs, like the '+' and ',' signs present in values on the 'Installs' column. We did that using the replace() method on the Series. The result was a string, but without the operator signs. We then used the to_numeric() function from Pandas to convert the Series from string (referred to in pandas as Object data type) to int64 type.

# %%
# Removing special characters from the 'Installs' column.

chars_to_replace = [',', '+']

for char in chars_to_replace:
    apps['Installs'] = apps['Installs'].str.replace(char, '', regex=False)
apps['Installs'] = pd.to_numeric(apps['Installs'], errors='raise')

# %% [markdown]
# We can see that the Installs column is now of data type int64.

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   App           9659 non-null   object
#  1   Category      9659 non-null   object
#  2   Rating        8196 non-null   float64
#  3   Reviews       9659 non-null   int64
#  4   Size          8432 non-null   float64
#  5   Installs      9659 non-null   int64
#  6   Type          9659 non-null   object
#  7   Price         9659 non-null   float64
#  8   Last Updated  9659 non-null   object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 679.3+ KB

# %% [markdown]
# Again, let's have a look at the modified apps DataFrame.

# %%
apps.sample(10)
# Out:
#                                  App             Category  Rating  Reviews  \
# 5628           Theme for Android 7.0      PERSONALIZATION     NaN        0
# 6697                         iReadMe         PRODUCTIVITY     5.0        8
# 646   GRE Prep & Practice by Magoosh            EDUCATION     4.4     3963
# 9485          FN FAL rifle explained  BOOKS_AND_REFERENCE     NaN        1
# 6267             Best CG Photography               FAMILY     NaN        1
# 6310                 DRAGON QUEST IV               FAMILY     4.7     1647
# 9361                      FK Liepaja               SPORTS     NaN        4
# 9400  Scratch-Off Guide for FL Lotto               FAMILY     4.6       25
# 3759  Grand Theft Auto V: The Manual               FAMILY     4.1   182103
# 5040                 BANGLA TV 3G/4G               SPORTS     4.1      142
#
#       Size  Installs  Type  Price       Last Updated
# 5628   NaN      5000  Free   0.00   October 18, 2017
# 6697  22.0       100  Free   0.00      March 6, 2018
# 646    NaN    100000  Free   0.00       June 6, 2018
# 9485   7.3        10  Paid   6.49  September 6, 2015
# 6267   2.5       500  Free   0.00      June 24, 2015
# 6310  16.0     10000  Paid  14.99  February 28, 2017
# 9361  26.0       100  Free   0.00     March 17, 2018
# 9400   5.6      5000  Free   0.00       July 4, 2018
# 3759   6.9   5000000  Free   0.00      July 31, 2018
# 5040   5.3    100000  Free   0.00       June 7, 2018

# %% [markdown]
# We can also see that the Date is of type 'str'. There is a special data type in Python, called datetime, which is used to process date/ time values. So, let's look at converting the values from the 'Last Updated' column to type datetime.
#
# pandas has a valuable function called to_datetime(), which is similar to the to_numeric() function we used earlier. However, in this function, we need to specify the format of the date/ time in the present column. For this, we can use metacharacters. Metacharacters are special characters that represent certain values in Python.
#
# I looked up the key for metacharacters at the strftime docs available at https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior.

# %%
date = pd.to_datetime(apps['Last Updated'], format = '%B %d, %Y')
apps['Last Updated'] = date

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   App           9659 non-null   object
#  1   Category      9659 non-null   object
#  2   Rating        8196 non-null   float64
#  3   Reviews       9659 non-null   int64
#  4   Size          8432 non-null   float64
#  5   Installs      9659 non-null   int64
#  6   Type          9659 non-null   object
#  7   Price         9659 non-null   float64
#  8   Last Updated  9659 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 679.3+ KB

# %% [markdown]
# For the next specified task, we were to find the number of apps in each category, the average price, and the average rating. The answer was to be saved as a DataFrame called app_category_info. Your should rename the four columns as: Category, Number of apps, Average price, Average rating.

# %%
no_apps_df = apps.groupby('Category')['App'].count()
avg_price_df = apps.groupby('Category')['Price'].agg('mean')
avg_rating_df = apps.groupby('Category')['Rating'].agg('mean')

# %%
app_category_info = pd.DataFrame(data = {
                     'Number of apps':no_apps_df, 
                     'Average price':avg_price_df, 
                     'Average rating':avg_rating_df})

# %%
app_category_info.reset_index()
# Out:
#                Category  Number of apps  Average price  Average rating
# 0        ART_AND_DESIGN              64       0.093281        4.357377
# 1     AUTO_AND_VEHICLES              85       0.158471        4.190411
# 2                BEAUTY              53       0.000000        4.278571
# 3   BOOKS_AND_REFERENCE             222       0.539505        4.344970
# 4              BUSINESS             420       0.417357        4.098479
# 5                COMICS              56       0.000000        4.181481
# 6         COMMUNICATION             315       0.263937        4.121484
# 7                DATING             171       0.160468        3.970149
# 8             EDUCATION             119       0.150924        4.364407
# 9         ENTERTAINMENT             102       0.078235        4.135294
# 10               EVENTS              64       1.718594        4.435556
# 11               FAMILY            1832       1.309967        4.179664
# 12              FINANCE             345       8.408203        4.115563
# 13       FOOD_AND_DRINK             112       0.075714        4.172340
# 14                 GAME             959       0.296465        4.247368
# 15   HEALTH_AND_FITNESS             288       0.223438        4.243033
# 16       HOUSE_AND_HOME              74       0.000000        4.150000
# 17   LIBRARIES_AND_DEMO              84       0.011786        4.178125
# 18            LIFESTYLE             369       6.398022        4.093355
# 19  MAPS_AND_NAVIGATION             131       0.205725        4.036441
# 20              MEDICAL             395       2.520759        4.166552
# 21   NEWS_AND_MAGAZINES             254       0.015669        4.121569
# 22            PARENTING              60       0.159667        4.300000
# 23      PERSONALIZATION             376       0.400213        4.332215
# 24          PHOTOGRAPHY             281       0.420925        4.157414
# 25         PRODUCTIVITY             374       0.670936        4.183389
# 26             SHOPPING             202       0.027129        4.230000
# 27               SOCIAL             239       0.066820        4.247291
# 28               SPORTS             325       0.307692        4.216154
# 29                TOOLS             827       0.323156        4.039554
# 30     TRAVEL_AND_LOCAL             219       0.228082        4.069519
# 31        VIDEO_PLAYERS             163       0.064172        4.044595
# 32              WEATHER              79       0.410380        4.243056

# %%
app_category_info['Number of apps'].sum()
# Out:
# 9659

# %%
# DATAFRAME CREATED, #2 DONE

apps.sample(10)
# Out:
#                                                   App             Category  \
# 2263                                  HD Camera Ultra          PHOTOGRAPHY
# 7145                       10,000 Quotes DB (Premium)  BOOKS_AND_REFERENCE
# 2786  Polaris Office - Word, Docs, Sheets, Slide, PDF         PRODUCTIVITY
# 5107                          Sexy Hot Detector Prank               FAMILY
# 5976                   SegPlay Mobile Paint by Number               FAMILY
# 206                                      Call Blocker             BUSINESS
# 1291                                          Safeway            LIFESTYLE
# 6557                                       Pokémon TV               FAMILY
# 2128                                      Rossmann PL             SHOPPING
# 2855                              Baby Care & Tracker            PARENTING
#
#       Rating  Reviews  Size  Installs  Type  Price       Last Updated
# 2263     4.3   462152   1.5  10000000  Free   0.00   October 17, 2015
# 7145     4.1       70   3.5       500  Paid   0.99    August 30, 2013
# 2786     4.3   549900  60.0  10000000  Free   0.00      July 18, 2018
# 5107     3.9    17067   2.7   5000000  Free   0.00  February 13, 2018
# 5976     3.7     1478  43.0    100000  Free   0.00     April 22, 2017
# 206      4.6   188841   3.2   5000000  Free   0.00      June 21, 2018
# 1291     4.3    33572  37.0   1000000  Free   0.00     August 2, 2018
# 6557     4.2   117461   NaN   5000000  Free   0.00      June 29, 2018
# 2128     4.0    15867   NaN   5000000  Free   0.00     August 6, 2018
# 2855     4.1      319  11.0    100000  Free   0.00      July 12, 2018

# %% [markdown]
# 328 FREE finance apps, 345 total

# %%
score_apps_table = apps.merge(reviews, on='App', how='inner')

# %%
score_apps_table.sample(5)
# Out:
#                                 App          Category  Rating  Reviews  Size  \
# 55224       ColorNote Notepad Notes      PRODUCTIVITY     4.6  2401017   NaN
# 56490                   HTC Gallery     VIDEO_PLAYERS     4.1    45744   NaN
# 27706                 Cooking Fever              GAME     4.5  3197865  82.0
# 47818  Cheapflights – Flight Search  TRAVEL_AND_LOCAL     4.4    47780  19.0
# 1452             Filters for Selfie            BEAUTY     4.3     8572  25.0
#
#         Installs  Type  Price   Last Updated  \
# 55224  100000000  Free    0.0  June 27, 2018
# 56490   10000000  Free    0.0   June 3, 2016
# 27706  100000000  Free    0.0  July 12, 2018
# 47818    5000000  Free    0.0  July 31, 2018
# 1452     1000000  Free    0.0   May 10, 2018
#
#                                                   Review Sentiment Category  \
# 55224  A useful particularly forgetful people like me...           Positive
# 56490                                                NaN                NaN
# 27706  Why drawback game??? I upgraded 100% upgrading...           Negative
# 47818                                          Very nice           Positive
# 1452   Disgusting.... I think good reviews paid.... !...           Negative
#
#        Sentiment Score
# 55224         0.191667
# 56490              NaN
# 27706        -0.400000
# 47818         0.780000
# 1452         -0.062500

# %%
finance_scores_table = score_apps_table[(score_apps_table['Category'] == 'FINANCE') & (score_apps_table['Type'] == 'Free')]

# %%
finance_scores_table
# Out:
#                                 App Category  Rating  Reviews  Size  Installs  \
# 14112             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14113             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14114             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14115             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14116             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14117             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14118             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14119             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14120             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14121             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14122             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14123             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14124             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14125             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14126             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14127             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14128             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14129             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14130             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14131             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14132             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14133             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14134             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14135             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14136             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14137             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14138             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14139             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14140             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# 14141             Citibanamex Movil  FINANCE     3.6    52306  42.0   5000000
# ...                             ...      ...     ...      ...   ...       ...
# 60206  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60207  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60208  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60209  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60210  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60211  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60212  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60213  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60214  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60215  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60216  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60217  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60218  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60219  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60220  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60221  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60222  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60223  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60224  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60225  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60226  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60227  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60228  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60229  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60230  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60231  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60232  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60233  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60234  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
# 60235  Fortune City - A Finance App  FINANCE     4.6    49275  91.0    500000
#
#        Type  Price   Last Updated  \
# 14112  Free    0.0  July 27, 2018
# 14113  Free    0.0  July 27, 2018
# 14114  Free    0.0  July 27, 2018
# 14115  Free    0.0  July 27, 2018
# 14116  Free    0.0  July 27, 2018
# 14117  Free    0.0  July 27, 2018
# 14118  Free    0.0  July 27, 2018
# 14119  Free    0.0  July 27, 2018
# 14120  Free    0.0  July 27, 2018
# 14121  Free    0.0  July 27, 2018
# 14122  Free    0.0  July 27, 2018
# 14123  Free    0.0  July 27, 2018
# 14124  Free    0.0  July 27, 2018
# 14125  Free    0.0  July 27, 2018
# 14126  Free    0.0  July 27, 2018
# 14127  Free    0.0  July 27, 2018
# 14128  Free    0.0  July 27, 2018
# 14129  Free    0.0  July 27, 2018
# 14130  Free    0.0  July 27, 2018
# 14131  Free    0.0  July 27, 2018
# 14132  Free    0.0  July 27, 2018
# 14133  Free    0.0  July 27, 2018
# 14134  Free    0.0  July 27, 2018
# 14135  Free    0.0  July 27, 2018
# 14136  Free    0.0  July 27, 2018
# 14137  Free    0.0  July 27, 2018
# 14138  Free    0.0  July 27, 2018
# 14139  Free    0.0  July 27, 2018
# 14140  Free    0.0  July 27, 2018
# 14141  Free    0.0  July 27, 2018
# ...     ...    ...            ...
# 60206  Free    0.0  July 17, 2018
# 60207  Free    0.0  July 17, 2018
# 60208  Free    0.0  July 17, 2018
# 60209  Free    0.0  July 17, 2018
# 60210  Free    0.0  July 17, 2018
# 60211  Free    0.0  July 17, 2018
# 60212  Free    0.0  July 17, 2018
# 60213  Free    0.0  July 17, 2018
# 60214  Free    0.0  July 17, 2018
# 60215  Free    0.0  July 17, 2018
# 60216  Free    0.0  July 17, 2018
# 60217  Free    0.0  July 17, 2018
# 60218  Free    0.0  July 17, 2018
# 60219  Free    0.0  July 17, 2018
# 60220  Free    0.0  July 17, 2018
# 60221  Free    0.0  July 17, 2018
# 60222  Free    0.0  July 17, 2018
# 60223  Free    0.0  July 17, 2018
# 60224  Free    0.0  July 17, 2018
# 60225  Free    0.0  July 17, 2018
# 60226  Free    0.0  July 17, 2018
# 60227  Free    0.0  July 17, 2018
# 60228  Free    0.0  July 17, 2018
# 60229  Free    0.0  July 17, 2018
# 60230  Free    0.0  July 17, 2018
# 60231  Free    0.0  July 17, 2018
# 60232  Free    0.0  July 17, 2018
# 60233  Free    0.0  July 17, 2018
# 60234  Free    0.0  July 17, 2018
# 60235  Free    0.0  July 17, 2018
#
#                                                   Review Sentiment Category  \
# 14112  Forget paying app, designed make fail payments...           Negative
# 14113  It's working expected, talking best bank Mexic...           Positive
# 14114  It has many problems with Android 8.1. You can...           Positive
# 14115  I changed my phone to a Xiaomi Redmi Note 5, t...           Positive
# 14116  In her eagerness to make her look pretty with ...           Negative
# 14117  I can not activate my mobile Netkey because it...           Positive
# 14118  The mobile netkey does not work on Android 8.1...            Neutral
# 14119  The new update is frozen on the home screen wi...           Positive
# 14120  Almost everything works well, only that the tr...            Neutral
# 14121  In my case after the update stopped working, t...           Positive
# 14122  2018-08-01: Android 8.1 is still supported ?, ...           Positive
# 14123  The whole system crashes (literally, causes th...           Positive
# 14124  It is not compatible with 8.1 gives many probl...           Positive
# 14125  The new update works very well in Samsung 7 Ed...           Positive
# 14126  I placed wrong fingerprint, I tried open sessi...           Negative
# 14127  Needs improvement. Wanted Mobile Netkey find I...           Negative
# 14128  I have purchased a new cell phone, keep saying...           Positive
# 14129  Horrible! You can not see the charges made unt...           Negative
# 14130  After some updates I can finally use the app, ...           Positive
# 14131  It's already good, only if you keep working in...           Positive
# 14132  If I dont sign I can't sign 10 minutes passed ...           Negative
# 14133  I LIKE A LOT, IT IS VERY ACCESSIBLE AND YOU CA...           Positive
# 14134  It is a great service although I had some prob...           Positive
# 14135  Back the problems that the operating system is...            Neutral
# 14136  I see that many complain, but the truth is tha...           Positive
# 14137  They keep uploading updates, the application k...           Negative
# 14138  Has improved a lot. At this moment it is a ver...           Positive
# 14139  It needs quick transfers save accounts/debit c...           Negative
# 14140  It works very well to review the accounts aest...           Positive
# 14141  The biggest change I noticed with the last upd...            Neutral
# ...                                                  ...                ...
# 60206                                                NaN                NaN
# 60207                                                NaN                NaN
# 60208                                                NaN                NaN
# 60209                                                NaN                NaN
# 60210                                                NaN                NaN
# 60211                                                NaN                NaN
# 60212                                                NaN                NaN
# 60213                                                NaN                NaN
# 60214                                                NaN                NaN
# 60215                                                NaN                NaN
# 60216                                                NaN                NaN
# 60217                                                NaN                NaN
# 60218                                                NaN                NaN
# 60219                                                NaN                NaN
# 60220                                                NaN                NaN
# 60221                                                NaN                NaN
# 60222                                                NaN                NaN
# 60223                                                NaN                NaN
# 60224                                                NaN                NaN
# 60225                                                NaN                NaN
# 60226                                                NaN                NaN
# 60227                                                NaN                NaN
# 60228                                                NaN                NaN
# 60229                                                NaN                NaN
# 60230                                                NaN                NaN
# 60231                                                NaN                NaN
# 60232                                                NaN                NaN
# 60233                                                NaN                NaN
# 60234                                                NaN                NaN
# 60235                                                NaN                NaN
#
#        Sentiment Score
# 14112        -0.500000
# 14113         0.400000
# 14114         0.250000
# 14115         0.175000
# 14116        -0.158333
# 14117         0.116667
# 14118         0.000000
# 14119         0.168182
# 14120         0.000000
# 14121         0.243750
# 14122         0.291667
# 14123         0.200000
# 14124         0.500000
# 14125         0.157576
# 14126        -0.126667
# 14127        -0.100000
# 14128         0.136364
# 14129        -0.187500
# 14130         0.455000
# 14131         0.175000
# 14132        -0.600000
# 14133         0.487500
# 14134         0.433333
# 14135         0.000000
# 14136         0.833333
# 14137        -0.097727
# 14138         0.505000
# 14139        -0.111111
# 14140         0.722000
# 14141         0.000000
# ...                ...
# 60206              NaN
# 60207              NaN
# 60208              NaN
# 60209              NaN
# 60210              NaN
# 60211              NaN
# 60212              NaN
# 60213              NaN
# 60214              NaN
# 60215              NaN
# 60216              NaN
# 60217              NaN
# 60218              NaN
# 60219              NaN
# 60220              NaN
# 60221              NaN
# 60222              NaN
# 60223              NaN
# 60224              NaN
# 60225              NaN
# 60226              NaN
# 60227              NaN
# 60228              NaN
# 60229              NaN
# 60230              NaN
# 60231              NaN
# 60232              NaN
# 60233              NaN
# 60234              NaN
# 60235              NaN
#
# [2200 rows x 12 columns]

# %%
top_10_user_feedback = finance_scores_table.groupby('App')['Sentiment Score'].agg('mean')

# %%
pd.Dara(top_10_user_feedback.shape)
# Out:
# (46,)

# %%
top_10.groupby('App')['Sentiment Score'].agg('mean').sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-318c7d0bdf02> in <module>
# ----> 1 top_10.groupby('App')['Sentiment Score'].agg('mean').sort_values(ascending = False)
#
# NameError: name 'top_10' is not defined

# %%
top_10_user_feedback = pd.DataFrame(top_10_user_feedback.groupby('App')['Sentiment Score'].agg('mean').sort_values(ascending=False)[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-246-14d17b819908> in <module>
# ----> 1 top_10_user_feedback = pd.DataFrame(top_10_user_feedback.groupby('App')['Sentiment Score'].agg('mean').sort_values(ascending=False)[:10])
#
# NameError: name 'top_10_user_feedback' is not defined

# %%
top_10_user_feedback
